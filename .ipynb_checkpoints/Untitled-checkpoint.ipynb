# %%
LACrime = read.csv("Crime_Data_2010_2017.csv")

# %%
hist(LACrime$Victim.Age, 
     border="blue", 
     col="green",
     xlim=c(0,100),
     las=1, 
     breaks=100)
# Out:
# Plot with title “Histogram of LACrime$Victim.Age”
